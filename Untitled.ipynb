# %%
4+5
# Out:
# 9

# %%
print(4+5)
# Out:
# 9

# %%
10/2
# Out:
# 5.0

# %%
10/2.0
# Out:
# 5.0

# %%
9/3
# Out:
# 3.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10/3.0
# Out:
# 3.3333333333333335

# %%
script.py
4+5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DELROY~1.NIC\AppData\Local\Temp/ipykernel_22312/9121503.py in <module>
# ----> 1 script.py
#       2 4+5
#
# NameError: name 'script' is not defined

# %%
# Create the areas list

# %% [raw]
# areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
# x=areas
# x as variable

# %%
print(x[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DELROY~1.NIC\AppData\Local\Temp/ipykernel_22312/3285389606.py in <module>
# ----> 1 print(x[1])
#
# NameError: name 'x' is not defined
