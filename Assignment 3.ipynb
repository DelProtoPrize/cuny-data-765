# %% [markdown]
# # Data765 | Lecture 4 | Structure Types & Control Flow (I)
# ## Assignment 3 (points: 5)
# ### Due: Oct 8 Tuesday by midnight
#
# ### Student Name: Delroy Nichols

# %% [markdown]
# # Q1: Structured Data Types (2 pts)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Suppose we have a dictionary <br>
#
#    <code>d = {'course_num': [123, 790, 765], 'instructor': ['Abby Lee', 'YINXIAN ZHANG', 'Henry Gomez'], 'workload': [3.5, 4.7, 5.8]}</code> <br>
#    <br>
# For each of the tasks below, write a **Python program** to complete the task **in  the given order**. <br>
#
#    <p style="margin-left: 30px"> 1. Use a proper string method to convert the element 'YINXIAN ZHANG' in <code>instructor</code> to a lowercased name. You need to save the output to the original variable to update the value.<br>
#    2. Change the first element of <code>course_num</code> to <code>710</code>.<br>
#    3. Use **multi-slicing** to get the fourth letter ("y") from the first name in <code>instructor</code>. Save it to a variable <code>char</code>.<br>
#    4. Add a new entry <code>enrollment</code> to <code>d</code>, with the value of <code>[15, 16, 13]</code>. **Print out** all the keys in <code>d</code>. <br>
#    5. What is the length of <code>d</code>? Save your answer to a variable <code>ans1</code>. <br>
#    6. Try to obtain the value associated with the (non-existing) key <code>'mode'</code> without triggering an error message. If the key does not exist, please return a string <code>'the key does not exist.'</code> Save the output to a variable <code>is_mode</code><br>
#    7. Check if the letter 'a' is in <code>instructor</code> in <code>d</code>. Save the output to a variable <code>ans2</code>. Then check if the letter 'a' is in the second name of <code>instructor</code> in <code>d</code>.Save the output to a variable <code>ans3</code>. Are the two answers the same? Please explain it in **a markdown cell** below your code cell.<br></p>
#
# <br>
#
# <b>Grading: Q1-Q5: 0.1 pts each; Q6: 0.2 pts; Q7: 0.3 pts. (2 pts total). You will get full points if you complete all tasks successfully.</b>
#
# </div>

# %%
# dictionary defined for you
d = {'course_num': [123, 790, 765], 
     'instructor': ['Abby Lee', 'YINXIAN ZHANG','Henry Gomez'], 
     'workload': [3.5, 4.7, 5.8]}

## your code below:

# Q1
x = d['instructor'][1]
w = x.lower()
d['instructor'][1] = w
print(d['instructor'][1])


# Q2
d['course_num'][0] = 710

# Q3
char = d['instructor'][0][3]

# Q4
d['enrollment'] = [15, 16, 13]
print(d.keys())
# Q5
ans1 = len(d)
print(ans1)

# Q6
is_mode = d.get('mode', 'the key does not exist')

# Q7
ans2 = 'a' in d['instructor']
ans3 = 'a' in d['instructor'][1]
### "the answers are not the same because ans2 checks all the values in the instructor key for the 'a' value, not the letter.""
### "ans 3 will check if the letter 'a' is contained within the second value"
# Out:
# yinxian zhang
# dict_keys(['course_num', 'instructor', 'workload', 'enrollment'])
# 4

# %%
## run this cell after you finish Q1:

print('1. The lowercased string is: ', d['instructor'][1])
print(f"2. The value of 'course_num' now is {d['course_num']}.")
print('3. The fourth letter of the first name is: ', char)
print('4. The keys in the dictionary are: ', d.keys())
print('5. The length of the modified dictionary is: ', ans1)
print('6. What is the value of the key "mode" in the dictionary: ', is_mode)
print('7. Are the two answers the same: ', ans2==ans3)

print()
print('Note: Please add a Markdown cell above or below to explain Q7: are the two answers the same? Why or Why not?')
### the answers are not the same because ans2 checks all the values in the instructor key for the 'a' value, not the letter.
### ans 3 will check if the letter 'a' is contained within the second value
# Out:
# 1. The lowercased string is:  yinxian zhang
# 2. The value of 'course_num' now is [710, 790, 765].
# 3. The fourth letter of the first name is:  y
# 4. The keys in the dictionary are:  dict_keys(['course_num', 'instructor', 'workload', 'enrollment'])
# 5. The length of the modified dictionary is:  4
# 6. What is the value of the key "mode" in the dictionary:  the key does not exist
# 7. Are the two answers the same:  False
#
# Note: Please add a Markdown cell above or below to explain Q7: are the two answers the same? Why or Why not?

# %% [markdown]
# # Q2: Conditional Programs (3 pts)

# %% [markdown]
# <div class="alert alert-block alert-success">
# Suppose that you want to use a decision tree as shown below to make your weekend plan. Please write a <code>if...elif...else...</code> conditional program to turn this decision tree into a Python program. Use <code> print </code> statement to show the output under different conditions as a string, such as <code> 'Stay in' </code> or <code> 'Go running' </code>. <br>
#
# <br>
# Hint: I initialized three variables for you, including <code> work </code> (for the boolean test "Work to do?". Takes two possible values), <code> outlook </code> (for the test "Outlook?". Takes three possible values), and <code> friend_busy </code> (for the test "Friends busy?" Takes two possible values). You can build your conditonal program using these variables. Note that I initialized the variables with random values. You may want to change these values to see how the output of your program changes accordingly.<br>
#     <br>
#     <br>
#
# <b>Grading:</b> <br>
#     The program consistently outputs correct answers for different inputs: 3 pts<br>
#     The program outputs correct answers for some inputs but not for others: 2-3 pts <br>
#     The program is buggy but it shows that you have a decent understanding of the concepts: 1-2 pts<br>
#     The program contains a substantial amount of bugs and/or only outputs error messages: 0 pts<br>
# </div>

# %% [markdown]
# <img src='https://static.commonlounge.com/fp/original/3gaQtwvzuLaAtx1HpaCG5Qgnl1520487539_kc' align = center width = 500>

# %%
# initialize variables
# You may change the values below to see how the output of your program changes accordingly.

work = 'entirety'                   # Takes 'Yes' or 'No' (case-sensitive)
outlook = 'Rainy'             # Takes 'Rainy', 'Overcast', or 'Sunny'  (case-sensitive)
friend_busy = 'Yes'           # Takes 'Yes' or 'No' (case-sensitive)

# %%
## Complete the code below: 

if work == 'Yes': 
    print('Stay In')
    
elif outlook == 'Sunny':
    print('Go to beach')
        
elif outlook == 'Overcast':
    print('Go running')
            
elif friend_busy == 'No':
    print('Go to movies')
else:
    print('Stay in')
# Out:
# Stay in
