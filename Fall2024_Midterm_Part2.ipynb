# %% [markdown]
# # Data765 | Fall 2024
# # Midterm Exam | Part 2
# ---
# ## Total points: 7.5 points
# ### Due: Oct 30, 10:30 PM.

# %% [markdown]
# <p style='color:red'>
# <b>Honor Pledge:</b>
# </p>
#
# Consistent with [The Academic Integrity Policy of The City University of New York](https://www.cuny.edu/about/administration/offices/legal-affairs/policies-procedures/academic-integrity-policy/), I agree that my answers to this midterm exam represent my work and my work only. I also understand that all forms of academic misconduct are prohibited including, but is not limited to, **communicating about the exam with anyone** except for the instructor during the exam, or **consulting external resources without acknowledgment**.
#
# Please sign below (double click the cell and type your legal name here):
#
#     Name:_Delroy Nichols___________  Date: 10/30/2024

# %% [markdown]
# ---
# # Q1: Reversed Strings (7.5 pts total)
#
# ### In this coding problem, you are asked to complete 3 tasks that are *built on top of each other*. Please follow the instructions below to solve the problem:

# %% [markdown]
# ## Q 1.1 (0.5 pts)
#
# Consider a string `s = "Python Fundamentals"`. Please write a program to reverse `s` (so that it becomes `"slatnemadnuF nohtyP"`), and save the reversed string to a variable `s_reversed`.

# %% [markdown]
# **Hint**
#
# You should NOT manually type out the reversed string. Instead, please use Python code to do this.

# %%
s = "Python Fundamentals"
## your code below:
def grace(s):
    s = "Python Fundamentals"
    for i in 's' :
        d = {}
        d['old'] = s
        b= len(s)
        for j in d['old'][::-1] :
            c = print(j)
    return c 
s_reversed=grace(s)
# Out:
# s
# l
# a
# t
# n
# e
# m
# a
# d
# n
# u
# F
#
# n
# o
# h
# t
# y
# P

# %%
## run this cell after you complete Q1.1

print(s_reversed)             # the output should be "slatnemadnuF nohtyP"
# Out:
# None

# %% [markdown]
# ---
# ## Q 1.2 (2 pts)
#
# Now, consider another string `s = "Anna? Anna, Anna!"`. Write a program to check if this string reads the same backward as forward. Save the output (`True` or `False`) to a variable `ans`. Note that the result should **NOT be influenced by punctuations, whitespaces, and/or case sensitivity.**

# %% [markdown]
# **Hints**
# 1. This question is built on top of Q1.1. To check whether the string reads the same backward as forward, **you can compare the string and its reversed string.**
# 2. You should deal with **non-alphabet** charaters (such as punctuations and whitespaces) and **case sensitivity** before the comparison, otherwise your results will be incorrect.
# 3. Think of a way to **find only alphabet letters** from the string. You may use a `for` loop to check each element of the string, and keep only alphabets.
# 4. You have learned about how to check whether an element is an alphabet -- use either a string method or certain string operations.

# %%
s = "Anna? Anna, Anna!"
## your code below:
c= s[::-1]
special = ['?', ',', '!']
def read_backwards(s, c) :
    for i in c.lower() :
        if i == 0 :
        m = {}
        m['old'] = i
        print(i)
        
    for i in s.lower():
        if i in special:
            del i

# %%
## run this cell after you complete Q1.2

print(ans)               # the output should be `True`
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DELROY~1.NIC\AppData\Local\Temp/ipykernel_5828/2237985960.py in <module>
#       1 ## run this cell after you complete Q1.2
#       2
# ----> 3 print(ans)               # the output should be `True`
#
# NameError: name 'ans' is not defined

# %% [markdown]
# ## Q 1.3 (5 pts)
#
# Finally, based on what you have done in Q1.1 and 1.2, please write a function `is_reverse(s)`.
#
# The function takes **one positional argument `s`** as input, where `s` is a **string of any length**. Then it checks whether the string reads the same backward as forward. If it reads the same, the function will return `True`. Otherwise, the function will return `False`.
#
# Note that this string could be a word, a phrase, or a sentence. But the result should **NOT be influenced by punctuations, whitespaces, and/or case sensitivity.**
#
# For instance, if the input is `'Eve'`, then calling `is_reverse('Eve')` will return a `True`. If the input is `"No lemon, no melon."`, the funtion should also return a `True`.
#
# *Note: if the input is an empty string, you could simply return a `True`. Or you could deal with this situation separately as you like.*

# %% [markdown]
# **Hints**
# 1. This question is built on top of both Q 1.1 and Q 1.2. So the hints for previous questions all apply here.
# 2. Don't forget about **input validity**.
# 3. Don't forget about **docstrings**.  -- **You will received reduced marks if you don't follow class examples to write proper docstrings!**

# %%
# your code below:

def is_reverse(s) :
    """
    Evaluates the given string if it is the same frontwards and backwards.
    
    Args:
        s (str): The string to be evaluated.
       
        
    Returns:
        bool: If the string reads the same both ways.
        """
    

c= s[::-1]
special = ['?', ',', '!']
    def read_backwards(s, c) :
        for i in c.lower() :
            if i == 0 :
                m = {}
                m['old'] = i
            print(i)
        
        for i in s.lower():
            if i in special:
                del i

# %%
# run this cell after you solve Q 1.3. 

print(is_reverse(''))
print(is_reverse('a'))
print(is_reverse('Eve'))
print(is_reverse("Madam, I'm Adam."))
print(is_reverse('Python Fundamentals'))
print(is_reverse(666))
